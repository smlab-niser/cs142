# %% [markdown]
# <a href="https://colab.research.google.com/github/smlab-niser/cs142/blob/main/lec1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Writing comments
# Comments have no execution power but are definitely helpful in making others (sometimes even yourself) understand your code.

# %%
# Hello World code 
print("hello")
print("hello ", "Subhankar ")
# Out:
# hello
# hello  Subhankar

# %% [markdown]
# # Variables

# %%
# Simple variables
message = " hello Subhankar"
print(message)
# Out:
#  hello Subhankar

# %% [markdown]
# ## Exercise 1.1
# 1. Store a message in a variable, and then print that message .
# 1. After 1, change the value of your variable to a new message, and print the new message .

# %% [markdown]
# # Datatypes

# %%
# A. Strings - a collection of characters

name = "subhankar mishra"
# some functions associated with it. 
print(name.title()) # converts first letter of every word to uppercase
print(name.upper()) # converts all the characters to uppercase

# Try lower()

# Concatenating
print("\nConcatenating strings ")
fname = "Subhankar"
lname = "Mishra"
name = fname + " " + lname # concat using + 
print(name)
# Out:
# Subhankar Mishra
# SUBHANKAR MISHRA
#
# Concatenating strings
# Subhankar Mishra

# %% [markdown]
# ## Exercise 1.2
# 1. Find a funny tweet and write it as "@ABC tweeted on 26 March: 'text of tweet'"
# 1. Try functions such as lstrip(), rstrip() and strip()
# 1. Try '\t' and '\n'

# %%
# B. Numbers - Integers, Floats

# Integers 
print("Integers ... ")
print(3 + 2)
print(3 * 2)
print(3 ** 2)

# Floats - numbers with a decimal point
print("Floats ... ")
print(0.3 + 0.2)
print(0.3 * 0.2)
print(0.3 ** 0.2)

print("The awesome number is", 2)
# Out:
# Integers ...
# 5
# 6
# 9
# Floats ...
# 0.5
# 0.06
# 0.7860030855966228
# The awesome number is 2

# %%
def printhello():
    print("hello")

# %%
printhello()
# Out:
# hello

# %%
print("Pi is {:.3f}".format(22/7))
# Out:
# Pi is 3.143
